# %% [markdown]
# # <center><font color = orange>Matplotlib</font></center>

# %% [markdown]
# https://towardsdatascience.com/the-last-matplotlib-tweaking-guide-youll-ever-need-dbd4374a1c1e

# %%
import pandas as pd

import matplotlib.pyplot as plt

from matplotlib import rcParams, cycler

# %%
df = pd.read_csv( 'https://raw.githubusercontent.com/blue-yonder/pydse/master/pydse/data/international-airline-passengers.csv' , sep = ';' )

# %%
df.head( 5 )
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
plt.plot( df[ 'Passengers' ] )

# %%
rcParams[ 'figure.figsize' ] = 16 , 8

# %%
plt.plot( df[ 'Passengers' ] )

# %%
rcParams[ 'axes.spines.top' ] = False

rcParams[ 'axes.spines.right' ] = False

# %%
plt.plot( df[ 'Passengers' ] )

# %%
rcParams[ 'lines.linewidth' ] = 3.5

# %%
plt.plot( df[ 'Passengers' ] )

# %%
rcParams[ 'axes.prop_cycle' ] = cycler( color = [ 'orange' ] )

# %%
plt.plot( df[ 'Passengers' ] )

# %%
rcParams[ 'xtick.labelsize' ] = 'xx-large'
rcParams[ 'ytick.labelsize' ] = 'xx-large'

# %%
plt.plot( df[ 'Passengers' ] )
