# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.datasets.samples_generator import make_blobs

# %%
import pickle

# %%
import pandas

# %%
# generate 2d classification dataset
X, y = make_blobs(n_samples=100, centers=2, n_features=4, random_state=1)

# %%
# fit final model
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
###### Save and Load Machine Learning Models in Python with scikit-learn

# %%
# save the model to disk
filename = 'finalized_model_logistic_regression.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
# New dataset
X_new, _ = make_blobs(n_samples=150, centers=2, n_features=4, random_state=1)

# %%
# load the model from disk

loaded_model = pickle.load( open( filename, 'rb') )

# Make class prediction y_new on X_new

y_new = loaded_model.predict(X_new)

# %%
# Probabilité d'appartenance aux classes ( 0 ou 1 )

y_new_prob = loaded_model.predict_proba(X_new)

# %%
# show the inputs and predicted outputs
for i in range(len(X_new)):
	#print("X=%s, Predicted=%s" % (X_new[i], y_new2[i]))
    #print( "X = {0} , Predicted = {1}".format( X_new[i] , y_new2[i] ) )
    print( "( Predicted : {0} ) _  p( y = 1 | X = {1} ) = {2}".format( y_new[i] , X_new[i] , y_new_prob[i][1] ) )
# Out:
# ( Predicted : 0 ) _  p( y = 1 | X = [-1.3830606   3.67321826 -9.16170778 -2.40998944] ) = 0.002831762064723156
# ( Predicted : 1 ) _  p( y = 1 | X = [ -6.92324165 -10.66953197  -6.87046365  -3.39790678] ) = 0.9998631232306544
# ( Predicted : 1 ) _  p( y = 1 | X = [-6.22402063 -8.25611532 -5.1278954  -3.13848804] ) = 0.9992620201167276
# ( Predicted : 1 ) _  p( y = 1 | X = [-7.32386504 -7.96393491 -6.83858451 -2.99909905] ) = 0.9988939890932379
# ( Predicted : 0 ) _  p( y = 1 | X = [ -0.75870396   3.72276201 -10.12060273  -4.88911798] ) = 0.001269494622642859
# ( Predicted : 0 ) _  p( y = 1 | X = [-0.6207353   6.59346952 -9.55634806 -4.05350378] ) = 0.00013961912062023259
# ( Predicted : 0 ) _  p( y = 1 | X = [ -0.54517693   3.81996593 -11.23456588  -3.07750962] ) = 0.0008784998952979419
# ( Predicted : 0 ) _  p( y = 1 | X = [-2.88961804  4.95702736 -9.20490564 -4.57687928] ) = 0.0013468602638840408
# ...
