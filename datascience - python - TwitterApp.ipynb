# %%
# Install a conda package in the current Jupyter kernel
import sys

# %%
# !conda install --yes --prefix {sys.prefix} cx_oracle
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: D:\Anaconda3
#
#   added / updated specs:
#     - cx_oracle
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.5.11               |           py36_0         1.0 MB
#     cx_oracle-6.4.1            |   py36h2fa13f4_0         154 KB
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following NEW packages will be INSTALLED:
#
#     cx_oracle: 6.4.1-py36h2fa13f4_0
#
# The following packages will be UPDATED:
#
#     conda:     4.5.4-py36_0         --> 4.5.11-py36_0
#
#
# ...
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# conda-4.5.11         |  1.0 MB |            |   0%
# ...

# %%
# !conda install --yes --prefix {sys.prefix} numpy
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\Anaconda2
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2018.1.18          |           py27_0         144 KB
#     openssl-1.0.2n             |       hc64555f_0         4.6 MB
#     ------------------------------------------------------------
#                                            Total:         4.8 MB
#
# The following packages will be UPDATED:
#
#     certifi: 2017.7.27.1-py27hf761292_0 --> 2018.1.18-py27_0
#     openssl: 1.0.2l-vc9h02d068b_2       --> 1.0.2n-hc64555f_0
#
#
# ...
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# certifi 2018.1.18:            |   0%
# certifi 2018.1.18: #######5   |  75%
# ...

# %%
# !{sys.executable} -m pip install numpy
# Out:
# ...
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install twitter
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install --upgrade json
# Out:
# ...
#   Could not find a version that satisfies the requirement json (from versions: )
# No matching distribution found for json

# %%
import twitter
import json

# %%
CONSUMER_KEY = 'KZZmfoImDCDA9bbMdErntXIyn'
CONSUMER_SECRET = 'sdMbCPCC1Qm6zA9QMwAitelzCsC1dbdDYgktGN6wKt0LnT7tWZ'
OAUTH_TOKEN = '919578068-LnHjYdoNsNri0uklZ9zVWRU1bRNvAonk9nM9KkcP'
OAUTH_TOKEN_SECRET = 'EcC8CHTEtPcgLHZW6F0gsfylgddFauRDT85alxYqb9i56'

# %%
auth = twitter.oauth.OAuth( OAUTH_TOKEN , OAUTH_TOKEN_SECRET , CONSUMER_KEY , CONSUMER_SECRET )

# %%
twitter_api = twitter.Twitter( auth = auth )

# %%
print( twitter_api )

# %%
#Exploring trending topics
WORLD_WOE_ID = 1
FR_WOE_ID = 23424819

# %%
#Trending topics WORLD / FR ( ORLEANS )
world_trends = twitter_api.trends.place( _id = WORLD_WOE_ID )
fr_trends = twitter_api.trends.place( _id = FR_WOE_ID )
print( world_trends )
print()
print( fr_trends )
# Out:
# [{'trends': [{'name': '樹木希林さん', 'url': 'http://twitter.com/search?q=%E6%A8%B9%E6%9C%A8%E5%B8%8C%E6%9E%97%E3%81%95%E3%82%93', 'promoted_content': None, 'query': '%E6%A8%B9%E6%9C%A8%E5%B8%8C%E6%9E%97%E3%81%95%E3%82%93', 'tweet_volume': 101731}, {'name': 'Canelo', 'url': 'http://twitter.com/search?q=Canelo', 'promoted_content': None, 'query': 'Canelo', 'tweet_volume': 586563}, {'name': '#ابعاد_ال_الشيخ_ياولي_العهد_٢', 'url': 'http://twitter.com/search?q=%23%D8%A7%D8%A8%D8%B9%D8%A7%D8%AF_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE_%D9%8A%D8%A7%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D9%A2', 'promoted_content': None, 'query': '%23%D8%A7%D8%A8%D8%B9%D8%A7%D8%AF_%D8%A7%D9%84_%D8%A7%D9%84%D8%B4%D9%8A%D8%AE_%D9%8A%D8%A7%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF_%D9%A2', 'tweet_volume': 15567}, {'name': '#متي_تكون_رومنسي', 'url': 'http://twitter.com/search?q=%23%D9%85%D8%AA%D9%8A_%D8%AA%D9%83%D9%88%D9%86_%D8%B1%D9%88%D9%85%D9%86%D8%B3%D9%8A', 'promoted_content': None, 'query':
# ...

# %%
print( json.dumps(fr_trends , indent = 1 ) )
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#JourneeSansVoiture",
#     "url": "http://twitter.com/search?q=%23JourneeSansVoiture",
#     "promoted_content": null,
#     "query": "%23JourneeSansVoiture",
#     "tweet_volume": null
#    },
#    {
#     "name": "Djamel Allam",
#     "url": "http://twitter.com/search?q=%22Djamel+Allam%22",
#     "promoted_content": null,
#     "query": "%22Djamel+Allam%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Zlatan",
#     "url": "http://twitter.com/search?q=Zlatan",
#     "promoted_content": null,
#     "query": "Zlatan",
#     "tweet_volume": 138889
#    },
#    {
#     "name": "#JEP2018",
#     "url": "http://twitter.com/search?q=%23JEP2018",
#     "promoted_content": null,
#     "query": "%23JEP2018",
#     "tweet_volume": 11971
#    },
#    {
#     "name": "#SMCOL",
#     "url": "http://twitter.com/search?q=%23SMCOL",
#     "promoted_content": null,
#     "query": "%23SMCOL",
#     "tweet_volume": 15706
#    },
#    {
# ...

# %%
#Commun WORLD & FR trending topics
world_trends_set = set( [trend['name'] for trend in world_trends[0]['trends']] )
fr_trends_set = set( [trend['name'] for trend in fr_trends[0]['trends']] )
common_trends = world_trends_set.intersection( fr_trends_set )
print( common_trends )
# Out:
# set()

# %%
#Tweets sur THELEM ASSURANCES
#q = '#thelem'
q = 'orleans'
count = 100
search_results = twitter_api.search.tweets( q = q , result_type = 'recent' , lang = 'fr' , count = count )

statuses = search_results['statuses']

for _ in range( 5 ) :
    print( "length of statuses" , len( statuses ) )
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError as e:
        break
        
kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])

search_results = twitter_api.search.tweets(**kwargs)
statuses += search_results['statuses']

print( json.dumps(statuses[0] , indent = 1) )
# Out:
# length of statuses 100
# length of statuses 100
# length of statuses 100
# length of statuses 100
# length of statuses 100
# {
#  "created_at": "Sun Sep 16 08:31:45 +0000 2018",
#  "id": 1041243227511242753,
#  "id_str": "1041243227511242753",
#  "text": "RT @allysonmrf: Si quelqu\u2019un a trouver un porte monnaie gris avec la main de fatma dessus, de l\u2019argent \u00e0 l\u2019int\u00e9rieur et une carte d\u2019identit\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "allysonmrf",
#     "name": "\ud83c\uddea\ud83c\uddf8",
#     "id": 917083541615366145,
#     "id_str": "917083541615366145",
#     "indices": [
#      3,
#      14
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "fr",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
# ...

# %%
q = '#orleans'
count = 100
search_results = twitter_api.search.tweets( q = q , result_type = 'recent' , count = count )
print( search_results )
# Out:
# {'statuses': [{'created_at': 'Sun Sep 16 08:09:26 +0000 2018', 'id': 1041237611673575426, 'id_str': '1041237611673575426', 'text': 'See our latest #Orléans, Centre-Val de Loire #job and click to apply: Techniciens de maintenance -… https://t.co/dCN0yfHJqO', 'truncated': True, 'entities': {'hashtags': [{'text': 'Orléans', 'indices': [15, 23]}, {'text': 'job', 'indices': [45, 49]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/dCN0yfHJqO', 'expanded_url': 'https://twitter.com/i/web/status/1041237611673575426', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [100, 123]}]}, 'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'}, 'source': '<a href="http://tweetmyjobs.com" rel="nofollow">SafeTweet by TweetMyJOBS</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1601135264, 'id_str': '1601135264', 'name': 'Federal-Mogul
# ...

# %%
search_results['statuses']
# Out:
# []
